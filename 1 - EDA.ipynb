# %% [markdown]
# ## Chargement des librairies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %% [markdown]
# ### Chargement de la BDD et création d'une copie sur laquelle travailler, puis affichage du head

# %%
df_2018_original = pd.read_csv("data-2018.csv")
df_2018 = df_2018_original.copy()
df_2018.head()
# Out:
#    sno  district       mandal      village    lat_gis   long_gis   gwl  \
# 0    1  ADILABAD     Adilabad     Adilabad  19.668300  78.524700  5.09
# 1    2  ADILABAD  Bazarhatnur  Bazarhatnur  19.458888  78.350833  5.10
# 2    3  ADILABAD  Gudihatnoor  Gudihatnoor  19.525555  78.512222  4.98
# 3    4  ADILABAD      Jainath      Jainath  19.730555  78.640000  5.75
# 4    5  ADILABAD      Narnoor      Narnoor  19.495665  78.852654  2.15
#
#               season    pH   E.C  ...    SO4     Na    K  Ca      Mg  \
# 0  postmonsoon 2018   8.28   745  ...   46.0   49.0  4.0  48  38.896
# 1  postmonsoon 2018   8.29   921  ...   68.0   42.0  5.0  56  63.206
# 2  postmonsoon 2018   7.69   510  ...   44.0   45.0  2.0  24  38.896
# 3  postmonsoon 2018   8.09   422  ...   35.0   27.0  1.0  32  19.448
# 4  postmonsoon 2018   8.21  2321  ...  280.0  298.0  5.0  56  92.378
#
#           T.H       SAR  Classification  RSC  meq  / L  Classification.1
# 0  279.934211  1.273328            C2S1      -1.198684              P.S.
# 1  399.893092  0.913166            C3S1      -3.397862              P.S.
# 2  219.934211  1.319284            C2S1      -0.398684              P.S.
# 3  159.967105  0.928155            C2S1       0.000658              P.S.
# 4  519.843750  5.682664            C4S2      -4.396875              P.S.
#
# [5 rows x 26 columns]

# %%
df_2019_original = pd.read_csv("data-2019.csv")
df_2019 = df_2019_original.copy()
df_2019.head()
# Out:
#    sno  district       mandal      village    lat_gis   long_gis   gwl  \
# 0    1  ADILABAD     Adilabad     Adilabad  19.668300  78.524700  6.45
# 1    2  ADILABAD  Bazarhatnur  Bazarhatnur  19.458888  78.350833  3.85
# 2    3  ADILABAD  Gudihatnoor  Gudihatnoor  19.525555  78.512222  4.45
# 3    4  ADILABAD      Jainath      Jainath  19.730555  78.640000  3.95
# 4    5  ADILABAD      Narnoor      Narnoor  19.495665  78.852654  2.15
#
#               season    pH    EC  ...  SO4-2    Na+     K+  Ca+2    Mg+2  \
# 0  post monsoon 2019  8.32  2355  ...  377.0  273.0  113.0  80.0  82.654
# 1  post monsoon 2019  8.30   565  ...   52.0   89.0   14.0  48.0   4.862
# 2  post monsoon 2019  8.12   766  ...   43.0   39.0   10.0  40.0  24.310
# 3  post monsoon 2019  7.09   555  ...   31.0   40.0    5.0  40.0  24.310
# 4  post monsoon 2019  7.97   735  ...   28.0   44.0   16.0  72.0  34.034
#
#           T.H       SAR  Classification  RSC  meq  / L  Classification.1
# 0  539.860197  5.108509            C4S2      -3.797204              P.S.
# 1  139.991776  3.196982            C2S1       1.200164              P.S.
# 2  199.958882  1.199130            C3S1      -0.199178              P.S.
# 3  199.958882  1.229877            C2S1       0.400822              P.S.
# 4  319.942434  0.996598            C2S1       0.401151              P.S.
#
# [5 rows x 26 columns]

# %%
df_2020_original = pd.read_csv("data-2020.csv")
df_2020 = df_2020_original.copy()
df_2020.head()
# Out:
#    sno  district       mandal      village    lat_gis   long_gis   gwl  \
# 0    1  ADILABAD     Adilabad     Adilabad  19.668300  78.524700  7.10
# 1    2  ADILABAD  Bazarhatnur  Bazarhatnur  19.458888  78.350833  3.35
# 2    3  ADILABAD  Gudihatnoor  Gudihatnoor  19.525555  78.512222  5.05
# 3    4  ADILABAD      Jainath      Jainath  19.730555  78.640000  2.10
# 4    5  ADILABAD      Narnoor      Narnoor  19.495665  78.852654  1.38
#
#               season  Unnamed: 8    pH  ...    SO4     Na    K    Ca      Mg  \
# 0  Post-monsoon 2020         NaN  8.01  ...  33.00  171.0  9.0  24.0  72.930
# 1  Post-monsoon 2020         NaN  7.77  ...  13.50   70.0  3.0  16.0  53.482
# 2  Post-monsoon 2020         NaN  8.21  ...  10.50   65.0  3.0  16.0  48.620
# 3  Post-monsoon 2020         NaN   8.3  ...   7.25   31.0  1.0  16.0  29.172
# 4  Post-monsoon 2020         NaN  7.67  ...  14.50  129.0  2.0  32.0   5.000
#
#           T.H       SAR  Classification  RSC  meq  / L  Classification.1
# 0  359.876645  3.919146            C3S1       0.602467              P.S.
# 1  259.909539  1.887814            C3S1      -0.198191              P.S.
# 2  239.917763  1.824544            C2S1       0.001645              P.S.
# 3  159.950658  1.065714            C2S1      -0.199013              P.S.
# 4   82.878289  6.160862            C2S1       3.742434              U.S.
#
# [5 rows x 27 columns]

# %%
df_2018.dtypes.value_counts()
# Out:
# float64    15
# object      6
# int64       5
# Name: count, dtype: int64

# %% [markdown]
# ### Suppression de feature inutile

# %%
df_2020 = df_2020.loc[:, ~df_2020.columns.str.contains('^Unnamed')]
df_2019=df_2019.rename(columns={"EC": "E.C", "CO_-2 ": "CO3", "HCO_ - ": "HCO3", "Cl -": "Cl", "F -": "F", "NO3- ": "NO3 ", "SO4-2": "SO4", "Na+": "Na", "K+": "K", "Mg+2": "Mg", "Ca+2": "Ca"})

# %% [markdown]
# ## Analyse des features

# %%
df_2020['pH']=df_2020['pH'].replace('8..05', '8.05')

# %%
for i in range(df_2018.columns.size):
    if df_2018[df_2018.columns[i]].dtype != df_2019[df_2019.columns[i]].dtype or df_2019[df_2019.columns[i]].dtype != df_2020[df_2020.columns[i]].dtype:
        print(f"{df_2018.columns[i]}, \"{df_2018[df_2018.columns[i]].dtype}\" \"{df_2019[df_2019.columns[i]].dtype}\" \"{df_2020[df_2020.columns[i]].dtype}\"")
# Out:
# pH, "float64" "float64" "object"
# CO3, "int64" "float64" "float64"
# HCO3, "float64" "int64" "int64"
# Ca, "int64" "float64" "float64"

# %%
df_2020['pH']=df_2020['pH'].astype(float)
df_2018['CO3']=df_2018['CO3'].astype(float)
df_2019['HCO3']=df_2019['HCO3'].astype(float)
df_2020['HCO3']=df_2020['HCO3'].astype(float)
df_2018['Ca']=df_2018['Ca'].astype(float)

# %%
frames = [df_2018, df_2019, df_2020]
df = pd.concat(frames, ignore_index=True)

# %%
df['Classification'].unique()
# Out:
# array(['C2S1', 'C3S1', 'C4S2', 'C4S1', 'C3S2', 'C4S4', 'C4S3', 'C1S1',
#        'C3S4', 'C3S3', 'C2S2', 'OG', 'O.G'], dtype=object)

# %%
df['Classification'] = df['Classification'].replace('C3S1', "Poor")
df['Classification'] = df['Classification'].replace('C2S1', "Moderate")
df['Classification'] = df['Classification'].replace('C4S2', "Bad")
df['Classification'] = df['Classification'].replace('C4S1', "Bad")
df['Classification'] = df['Classification'].replace('C3S2', "Poor")
df['Classification'] = df['Classification'].replace('C4S4', "Bad")
df['Classification'] = df['Classification'].replace('C4S3', "Bad")
df['Classification'] = df['Classification'].replace('C1S1', "Good")
df['Classification'] = df['Classification'].replace('C3S4', "Bad")
df['Classification'] = df['Classification'].replace('C3S3', "Poor")
df['Classification'] = df['Classification'].replace('C2S2', "Moderate")
df = df[df.Classification != "OG"]
df = df[df.Classification != "O.G"]

# %%
df['Classification'].unique()
# Out:
# array(['Moderate', 'Poor', 'Bad', 'Good'], dtype=object)

# %% [markdown]
# ### Affichage des données manquantes, puis de leur pourcentage pour chaque catégorie

# %%
print(df.isna().sum())
print(df.isna().sum()/df.shape[0])
# Out:
# sno                   0
# district              0
# mandal                0
# village               0
# lat_gis               0
# long_gis              0
# gwl                  11
# season                0
# pH                    0
# E.C                   0
# TDS                   0
# CO3                 160
# HCO3                  0
# Cl                    0
# F                     0
# NO3                   0
# SO4                   0
# Na                    0
# K                     0
# Ca                    0
# Mg                    0
# T.H                   0
# SAR                   0
# Classification        0
# RSC  meq  / L         0
# Classification.1      0
# dtype: int64
# sno                 0.000000
# district            0.000000
# mandal              0.000000
# village             0.000000
# lat_gis             0.000000
# long_gis            0.000000
# gwl                 0.009982
# season              0.000000
# pH                  0.000000
# E.C                 0.000000
# TDS                 0.000000
# CO3                 0.145191
# HCO3                0.000000
# Cl                  0.000000
# F                   0.000000
# NO3                 0.000000
# SO4                 0.000000
# Na                  0.000000
# K                   0.000000
# Ca                  0.000000
# Mg                  0.000000
# T.H                 0.000000
# SAR                 0.000000
# Classification      0.000000
# RSC  meq  / L       0.000000
# Classification.1    0.000000
# dtype: float64

# %% [markdown]
# ### Affichage d'une heatmap

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isna(), cbar=False)
# Out:
# <Axes: >

# %%
ct = 0
for i in df['Classification']:
    print(ct,i)
    ct+=1
# Out:
# 0 Moderate
# 1 Poor
# 2 Moderate
# 3 Moderate
# 4 Bad
# 5 Poor
# 6 Poor
# 7 Poor
# 8 Bad
# 9 Moderate
# 10 Poor
# 11 Poor
# 12 Poor
# 13 Bad
# 14 Poor
# 15 Poor
# 16 Bad
# 17 Moderate
# 18 Poor
# 19 Moderate
# 20 Poor
# 21 Poor
# 22 Poor
# 23 Poor
# 24 Moderate
# 25 Moderate
# 26 Moderate
# 27 Poor
# 28 Poor
# 29 Poor
# 30 Poor
# 31 Poor
# 32 Poor
# 33 Poor
# 34 Poor
# 35 Poor
# 36 Poor
# 37 Poor
# 38 Poor
# 39 Moderate
# 40 Poor
# 41 Moderate
# 42 Poor
# 43 Poor
# 44 Poor
# 45 Poor
# 46 Poor
# 47 Moderate
# 48 Poor
# 49 Poor
# 50 Moderate
# 51 Poor
# 52 Poor
# 53 Poor
# 54 Moderate
# 55 Poor
# 56 Poor
# 57 Bad
# 58 Poor
# 59 Poor
# 60 Bad
# 61 Poor
# 62 Bad
# 63 Poor
# 64 Moderate
# 65 Poor
# 66 Bad
# 67 Bad
# 68 Poor
# 69 Poor
# 70 Poor
# 71 Poor
# 72 Poor
# 73 Poor
# 74 Poor
# 75 Poor
# 76 Bad
# 77 Moderate
# 78 Poor
# 79 Poor
# 80 Moderate
# 81 Moderate
# 82 Poor
# 83 Poor
# 84 Moderate
# 85 Moderate
# 86 Poor
# 87 Moderate
# 88 Poor
# 89 Moderate
# 90 Moderate
# 91 Moderate
# 92 Poor
# 93 Moderate
# 94 Bad
# 95 Poor
# 96 Poor
# 97 Bad
# 98 Poor
# 99 Poor
# 100 Poor
# 101 Poor
# 102 Poor
# 103 Moderate
# 104 Poor
# 105 Poor
# 106 Poor
# 107 Poor
# 108 Poor
# 109 Poor
# 110 Moderate
# 111 Moderate
# 112 Moderate
# 113 Moderate
# 114 Moderate
# 115 Poor
# 116 Poor
# 117 Poor
# 118 Poor
# 119 Poor
# 120 Poor
# 121 Good
# 122 Poor
# 123 Moderate
# 124 Moderate
# 125 Moderate
# 126 Moderate
# 127 Poor
# 128 Poor
# 129 Poor
# 130 Poor
# 131 Poor
# 132 Poor
# 133 Poor
# 134 Poor
# 135 Poor
# 136 Moderate
# 137 Bad
# 138 Poor
# 139 Moderate
# 140 Moderate
# 141 Poor
# 142 Poor
# 143 Poor
# 144 Poor
# 145 Poor
# 146 Bad
# 147 Poor
# 148 Poor
# 149 Poor
# 150 Bad
# 151 Poor
# 152 Poor
# 153 Moderate
# 154 Poor
# 155 Moderate
# 156 Bad
# 157 Moderate
# 158 Moderate
# 159 Moderate
# 160 Poor
# 161 Poor
# 162 Bad
# 163 Moderate
# 164 Poor
# 165 Poor
# 166 Poor
# 167 Good
# 168 Moderate
# 169 Poor
# 170 Poor
# 171 Poor
# 172 Poor
# 173 Poor
# 174 Poor
# 175 Poor
# 176 Bad
# 177 Poor
# 178 Poor
# 179 Bad
# 180 Poor
# 181 Poor
# 182 Bad
# 183 Poor
# 184 Bad
# 185 Moderate
# 186 Poor
# 187 Poor
# 188 Poor
# 189 Bad
# 190 Poor
# 191 Poor
# 192 Poor
# 193 Poor
# 194 Poor
# 195 Moderate
# 196 Bad
# 197 Poor
# 198 Moderate
# 199 Bad
# 200 Poor
# 201 Bad
# 202 Bad
# 203 Poor
# 204 Poor
# 205 Poor
# 206 Poor
# 207 Poor
# 208 Poor
# 209 Poor
# 210 Moderate
# 211 Poor
# 212 Bad
# 213 Poor
# 214 Poor
# 215 Poor
# 216 Moderate
# 217 Bad
# 218 Poor
# 219 Bad
# 220 Bad
# 221 Poor
# 222 Poor
# 223 Poor
# 224 Poor
# 225 Poor
# 226 Poor
# 227 Poor
# 228 Poor
# 229 Bad
# 230 Moderate
# 231 Moderate
# 232 Moderate
# 233 Poor
# 234 Moderate
# 235 Moderate
# 236 Moderate
# 237 Moderate
# 238 Moderate
# 239 Moderate
# 240 Poor
# 241 Poor
# 242 Bad
# 243 Poor
# 244 Poor
# 245 Moderate
# 246 Poor
# 247 Moderate
# 248 Poor
# 249 Poor
# 250 Poor
# 251 Poor
# 252 Poor
# 253 Poor
# 254 Poor
# 255 Poor
# 256 Poor
# 257 Poor
# 258 Poor
# 259 Poor
# 260 Poor
# 261 Poor
# 262 Poor
# 263 Poor
# 264 Poor
# 265 Poor
# 266 Poor
# 267 Poor
# 268 Poor
# 269 Moderate
# 270 Poor
# 271 Poor
# 272 Moderate
# 273 Bad
# 274 Poor
# 275 Bad
# 276 Poor
# 277 Poor
# 278 Poor
# 279 Poor
# 280 Poor
# 281 Poor
# 282 Bad
# 283 Poor
# 284 Moderate
# 285 Poor
# 286 Poor
# 287 Poor
# 288 Poor
# 289 Poor
# 290 Moderate
# 291 Moderate
# 292 Poor
# 293 Poor
# 294 Poor
# 295 Poor
# 296 Poor
# 297 Moderate
# 298 Poor
# 299 Moderate
# 300 Poor
# 301 Poor
# 302 Moderate
# 303 Moderate
# 304 Moderate
# 305 Poor
# 306 Moderate
# 307 Poor
# 308 Poor
# 309 Moderate
# 310 Poor
# 311 Poor
# 312 Poor
# 313 Poor
# 314 Poor
# 315 Poor
# 316 Poor
# 317 Poor
# 318 Poor
# 319 Poor
# 320 Moderate
# 321 Poor
# 322 Moderate
# 323 Poor
# 324 Poor
# 325 Moderate
# 326 Poor
# 327 Moderate
# 328 Moderate
# 329 Moderate
# 330 Moderate
# 331 Poor
# 332 Moderate
# 333 Poor
# 334 Moderate
# 335 Moderate
# 336 Poor
# 337 Bad
# 338 Poor
# 339 Poor
# 340 Poor
# 341 Poor
# 342 Bad
# 343 Bad
# 344 Moderate
# 345 Moderate
# 346 Moderate
# 347 Poor
# 348 Poor
# 349 Moderate
# 350 Poor
# 351 Poor
# 352 Poor
# 353 Poor
# 354 Moderate
# 355 Poor
# 356 Poor
# 357 Poor
# 358 Poor
# 359 Bad
# 360 Moderate
# 361 Poor
# 362 Bad
# 363 Poor
# 364 Poor
# 365 Poor
# 366 Poor
# 367 Poor
# 368 Bad
# 369 Poor
# 370 Bad
# 371 Poor
# 372 Bad
# 373 Poor
# 374 Bad
# 375 Moderate
# 376 Poor
# 377 Moderate
# 378 Moderate
# 379 Poor
# 380 Poor
# 381 Moderate
# 382 Poor
# 383 Moderate
# 384 Poor
# 385 Moderate
# 386 Poor
# 387 Bad
# 388 Poor
# 389 Poor
# 390 Bad
# 391 Moderate
# 392 Moderate
# 393 Moderate
# 394 Bad
# 395 Poor
# 396 Moderate
# 397 Moderate
# 398 Moderate
# 399 Moderate
# 400 Poor
# 401 Poor
# 402 Poor
# 403 Poor
# 404 Moderate
# 405 Poor
# 406 Poor
# 407 Poor
# 408 Poor
# 409 Bad
# 410 Poor
# 411 Poor
# 412 Poor
# 413 Poor
# 414 Poor
# 415 Moderate
# 416 Poor
# 417 Bad
# 418 Poor
# 419 Poor
# 420 Poor
# 421 Poor
# 422 Poor
# 423 Moderate
# 424 Poor
# 425 Poor
# 426 Poor
# 427 Moderate
# 428 Poor
# 429 Poor
# 430 Bad
# 431 Poor
# 432 Poor
# 433 Bad
# 434 Poor
# 435 Poor
# 436 Poor
# 437 Moderate
# 438 Poor
# 439 Bad
# 440 Bad
# 441 Poor
# 442 Poor
# 443 Poor
# 444 Poor
# 445 Poor
# 446 Moderate
# 447 Poor
# 448 Bad
# 449 Moderate
# 450 Poor
# 451 Poor
# 452 Poor
# 453 Poor
# 454 Poor
# 455 Poor
# 456 Bad
# 457 Moderate
# 458 Moderate
# 459 Moderate
# 460 Poor
# 461 Moderate
# 462 Poor
# 463 Moderate
# 464 Poor
# 465 Poor
# 466 Bad
# 467 Poor
# 468 Bad
# 469 Bad
# 470 Poor
# 471 Poor
# 472 Poor
# 473 Moderate
# 474 Poor
# 475 Moderate
# 476 Poor
# 477 Poor
# 478 Bad
# 479 Poor
# 480 Poor
# 481 Poor
# 482 Poor
# 483 Poor
# 484 Moderate
# 485 Moderate
# 486 Poor
# 487 Poor
# 488 Poor
# 489 Poor
# 490 Moderate
# 491 Poor
# 492 Poor
# 493 Poor
# 494 Moderate
# 495 Moderate
# 496 Poor
# 497 Poor
# 498 Poor
# 499 Poor
# 500 Poor
# 501 Poor
# 502 Moderate
# 503 Poor
# 504 Bad
# 505 Poor
# 506 Moderate
# 507 Moderate
# 508 Poor
# 509 Poor
# 510 Moderate
# 511 Moderate
# 512 Poor
# 513 Moderate
# 514 Poor
# 515 Bad
# 516 Poor
# 517 Bad
# 518 Poor
# 519 Poor
# 520 Poor
# 521 Bad
# 522 Bad
# 523 Poor
# 524 Poor
# 525 Poor
# 526 Moderate
# 527 Bad
# 528 Poor
# 529 Poor
# 530 Moderate
# 531 Poor
# 532 Poor
# 533 Moderate
# 534 Poor
# 535 Poor
# 536 Poor
# 537 Moderate
# 538 Moderate
# 539 Moderate
# 540 Poor
# 541 Poor
# 542 Poor
# 543 Poor
# 544 Bad
# 545 Poor
# 546 Poor
# 547 Bad
# 548 Poor
# 549 Bad
# 550 Bad
# 551 Poor
# 552 Bad
# 553 Bad
# 554 Poor
# 555 Bad
# 556 Poor
# 557 Poor
# 558 Moderate
# 559 Poor
# 560 Poor
# 561 Poor
# 562 Poor
# 563 Poor
# 564 Poor
# 565 Poor
# 566 Moderate
# 567 Moderate
# 568 Bad
# 569 Poor
# 570 Bad
# 571 Poor
# 572 Poor
# 573 Poor
# 574 Moderate
# 575 Poor
# 576 Bad
# 577 Poor
# 578 Bad
# 579 Poor
# 580 Poor
# 581 Poor
# 582 Moderate
# 583 Bad
# 584 Poor
# 585 Poor
# 586 Poor
# 587 Moderate
# 588 Poor
# 589 Bad
# 590 Poor
# 591 Poor
# 592 Poor
# 593 Poor
# 594 Poor
# 595 Poor
# 596 Moderate
# 597 Poor
# 598 Moderate
# 599 Moderate
# 600 Moderate
# 601 Moderate
# 602 Moderate
# 603 Moderate
# 604 Poor
# 605 Poor
# 606 Poor
# 607 Poor
# 608 Poor
# 609 Moderate
# 610 Poor
# 611 Moderate
# 612 Poor
# 613 Poor
# 614 Poor
# 615 Poor
# 616 Poor
# 617 Poor
# 618 Moderate
# 619 Poor
# 620 Poor
# 621 Poor
# 622 Poor
# 623 Poor
# 624 Poor
# 625 Poor
# 626 Poor
# 627 Poor
# 628 Poor
# 629 Moderate
# 630 Poor
# 631 Poor
# 632 Poor
# 633 Bad
# 634 Poor
# 635 Bad
# 636 Poor
# 637 Bad
# 638 Poor
# 639 Poor
# 640 Poor
# 641 Poor
# 642 Poor
# 643 Poor
# 644 Poor
# 645 Bad
# 646 Poor
# 647 Poor
# 648 Bad
# 649 Poor
# 650 Poor
# 651 Moderate
# 652 Moderate
# 653 Poor
# 654 Poor
# 655 Poor
# 656 Poor
# 657 Poor
# 658 Moderate
# 659 Moderate
# 660 Poor
# 661 Poor
# 662 Moderate
# 663 Moderate
# 664 Moderate
# 665 Poor
# 666 Moderate
# 667 Poor
# 668 Moderate
# 669 Poor
# 670 Poor
# 671 Poor
# 672 Poor
# 673 Poor
# 674 Poor
# 675 Poor
# 676 Poor
# 677 Poor
# 678 Poor
# 679 Bad
# 680 Poor
# 681 Poor
# 682 Poor
# 683 Poor
# 684 Poor
# 685 Poor
# 686 Poor
# 687 Poor
# 688 Good
# 689 Moderate
# 690 Poor
# 691 Poor
# 692 Moderate
# 693 Poor
# 694 Moderate
# 695 Moderate
# 696 Poor
# 697 Poor
# 698 Poor
# 699 Poor
# 700 Moderate
# 701 Poor
# 702 Poor
# 703 Bad
# 704 Bad
# 705 Moderate
# 706 Bad
# 707 Poor
# 708 Poor
# 709 Moderate
# 710 Poor
# 711 Poor
# 712 Poor
# 713 Poor
# 714 Poor
# 715 Poor
# 716 Poor
# 717 Poor
# 718 Poor
# 719 Poor
# 720 Moderate
# 721 Poor
# 722 Poor
# 723 Bad
# 724 Poor
# 725 Poor
# 726 Poor
# 727 Poor
# 728 Poor
# 729 Poor
# 730 Poor
# 731 Bad
# 732 Poor
# 733 Poor
# 734 Poor
# 735 Poor
# 736 Poor
# 737 Poor
# 738 Moderate
# 739 Moderate
# 740 Moderate
# 741 Poor
# 742 Poor
# 743 Poor
# 744 Poor
# 745 Moderate
# 746 Poor
# 747 Poor
# 748 Moderate
# 749 Bad
# 750 Poor
# 751 Poor
# 752 Bad
# 753 Moderate
# 754 Poor
# 755 Poor
# 756 Poor
# 757 Poor
# 758 Poor
# 759 Moderate
# 760 Moderate
# 761 Moderate
# 762 Moderate
# 763 Poor
# 764 Poor
# 765 Moderate
# 766 Poor
# 767 Moderate
# 768 Poor
# 769 Poor
# 770 Poor
# 771 Poor
# 772 Poor
# 773 Poor
# 774 Poor
# 775 Moderate
# 776 Poor
# 777 Poor
# 778 Moderate
# 779 Moderate
# 780 Poor
# 781 Poor
# 782 Poor
# 783 Moderate
# 784 Poor
# 785 Poor
# 786 Moderate
# 787 Poor
# 788 Poor
# 789 Poor
# 790 Moderate
# 791 Poor
# 792 Poor
# 793 Poor
# 794 Poor
# 795 Bad
# 796 Bad
# 797 Poor
# 798 Bad
# 799 Poor
# 800 Poor
# 801 Poor
# 802 Bad
# 803 Poor
# 804 Poor
# 805 Poor
# 806 Poor
# 807 Poor
# 808 Poor
# 809 Poor
# 810 Poor
# 811 Bad
# 812 Moderate
# 813 Moderate
# 814 Poor
# 815 Poor
# 816 Poor
# 817 Poor
# 818 Poor
# 819 Poor
# 820 Poor
# 821 Moderate
# 822 Moderate
# 823 Poor
# 824 Moderate
# 825 Poor
# 826 Poor
# 827 Poor
# 828 Moderate
# 829 Poor
# 830 Poor
# 831 Bad
# 832 Poor
# 833 Moderate
# 834 Poor
# 835 Poor
# 836 Moderate
# 837 Poor
# 838 Poor
# 839 Bad
# 840 Poor
# 841 Bad
# 842 Moderate
# 843 Poor
# 844 Poor
# 845 Moderate
# 846 Moderate
# 847 Moderate
# 848 Poor
# 849 Moderate
# 850 Poor
# 851 Poor
# 852 Poor
# 853 Moderate
# 854 Poor
# 855 Moderate
# 856 Poor
# 857 Moderate
# 858 Poor
# 859 Bad
# 860 Poor
# 861 Poor
# 862 Poor
# 863 Poor
# 864 Poor
# 865 Moderate
# 866 Poor
# 867 Poor
# 868 Bad
# 869 Poor
# 870 Poor
# 871 Poor
# 872 Poor
# 873 Poor
# 874 Moderate
# 875 Moderate
# 876 Poor
# 877 Poor
# 878 Poor
# 879 Bad
# 880 Poor
# 881 Poor
# 882 Poor
# 883 Poor
# 884 Bad
# 885 Poor
# 886 Bad
# 887 Poor
# 888 Poor
# 889 Poor
# 890 Poor
# 891 Poor
# 892 Bad
# 893 Moderate
# 894 Poor
# 895 Poor
# 896 Moderate
# 897 Moderate
# 898 Bad
# 899 Poor
# 900 Poor
# 901 Moderate
# 902 Moderate
# 903 Poor
# 904 Moderate
# 905 Poor
# 906 Poor
# 907 Poor
# 908 Poor
# 909 Bad
# 910 Poor
# 911 Bad
# 912 Bad
# 913 Moderate
# 914 Bad
# 915 Poor
# 916 Poor
# 917 Poor
# 918 Poor
# 919 Poor
# 920 Poor
# 921 Poor
# 922 Moderate
# 923 Poor
# 924 Poor
# 925 Poor
# 926 Poor
# 927 Bad
# 928 Poor
# 929 Moderate
# 930 Poor
# 931 Poor
# 932 Bad
# 933 Bad
# 934 Moderate
# 935 Poor
# 936 Poor
# 937 Poor
# 938 Poor
# 939 Poor
# 940 Poor
# 941 Poor
# 942 Poor
# 943 Poor
# 944 Poor
# 945 Moderate
# 946 Moderate
# 947 Poor
# 948 Poor
# 949 Bad
# 950 Poor
# 951 Poor
# 952 Poor
# 953 Bad
# 954 Poor
# 955 Bad
# 956 Poor
# 957 Poor
# 958 Bad
# 959 Poor
# 960 Poor
# 961 Poor
# 962 Poor
# 963 Poor
# 964 Poor
# 965 Moderate
# 966 Moderate
# 967 Poor
# 968 Poor
# 969 Moderate
# 970 Poor
# 971 Poor
# 972 Bad
# 973 Poor
# 974 Poor
# 975 Poor
# 976 Poor
# 977 Poor
# 978 Poor
# 979 Poor
# 980 Poor
# 981 Poor
# 982 Poor
# 983 Poor
# 984 Poor
# 985 Poor
# 986 Poor
# 987 Poor
# 988 Bad
# 989 Poor
# 990 Poor
# 991 Poor
# 992 Poor
# 993 Poor
# 994 Poor
# 995 Moderate
# 996 Poor
# 997 Moderate
# 998 Moderate
# 999 Moderate
# 1000 Bad
# 1001 Moderate
# 1002 Poor
# 1003 Poor
# 1004 Poor
# 1005 Poor
# 1006 Poor
# 1007 Bad
# 1008 Poor
# 1009 Poor
# 1010 Poor
# 1011 Bad
# 1012 Poor
# 1013 Poor
# 1014 Poor
# 1015 Bad
# 1016 Poor
# 1017 Poor
# 1018 Bad
# 1019 Moderate
# 1020 Moderate
# 1021 Poor
# 1022 Poor
# 1023 Bad
# 1024 Bad
# 1025 Poor
# 1026 Poor
# 1027 Poor
# 1028 Moderate
# 1029 Poor
# 1030 Poor
# 1031 Poor
# 1032 Poor
# 1033 Moderate
# 1034 Moderate
# 1035 Poor
# 1036 Poor
# 1037 Poor
# 1038 Poor
# 1039 Poor
# 1040 Poor
# 1041 Poor
# 1042 Poor
# 1043 Poor
# 1044 Poor
# 1045 Poor
# 1046 Poor
# 1047 Bad
# 1048 Moderate
# 1049 Bad
# 1050 Moderate
# 1051 Poor
# 1052 Moderate
# 1053 Bad
# 1054 Poor
# 1055 Moderate
# 1056 Moderate
# 1057 Moderate
# 1058 Moderate
# 1059 Poor
# 1060 Moderate
# 1061 Poor
# 1062 Moderate
# 1063 Moderate
# 1064 Moderate
# 1065 Moderate
# 1066 Poor
# 1067 Moderate
# 1068 Poor
# 1069 Moderate
# 1070 Moderate
# 1071 Bad
# 1072 Bad
# 1073 Moderate
# 1074 Poor
# 1075 Poor
# 1076 Moderate
# 1077 Bad
# 1078 Poor
# 1079 Poor
# 1080 Moderate
# 1081 Poor
# 1082 Poor
# 1083 Poor
# 1084 Poor
# 1085 Poor
# 1086 Poor
# 1087 Poor
# 1088 Poor
# 1089 Poor
# 1090 Poor
# 1091 Poor
# 1092 Poor
# 1093 Moderate
# 1094 Poor
# 1095 Bad
# 1096 Moderate
# 1097 Bad
# 1098 Poor
# 1099 Poor
# 1100 Bad
# 1101 Bad

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1102 entries, 0 to 1105
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sno               1102 non-null   int64
#  1   district          1102 non-null   object
#  2   mandal            1102 non-null   object
#  3   village           1102 non-null   object
#  4   lat_gis           1102 non-null   float64
#  5   long_gis          1102 non-null   float64
#  6   gwl               1091 non-null   float64
#  7   season            1102 non-null   object
#  8   pH                1102 non-null   float64
#  9   E.C               1102 non-null   int64
#  10  TDS               1102 non-null   float64
#  11  CO3               942 non-null    float64
#  12  HCO3              1102 non-null   float64
#  13  Cl                1102 non-null   int64
#  14  F                 1102 non-null   float64
#  15  NO3               1102 non-null   float64
#  16  SO4               1102 non-null   float64
#  17  Na                1102 non-null   float64
#  18  K                 1102 non-null   float64
#  19  Ca                1102 non-null   float64
#  20  Mg                1102 non-null   float64
#  21  T.H               1102 non-null   float64
#  22  SAR               1102 non-null   float64
#  23  Classification    1102 non-null   object
#  24  RSC  meq  / L     1102 non-null   float64
#  25  Classification.1  1102 non-null   object
# dtypes: float64(17), int64(3), object(6)
# memory usage: 232.5+ KB

# %% [markdown]
# ### Création des fonctions de traitement des données manquantes

# %%
df=df.drop(['sno', 'district', 'mandal', 'village', "lat_gis", "long_gis", "season", "Classification.1", "CO3", "gwl"], axis=1)

# %%
columns = [i for i in df if df[i].isna().sum()!=0]
print(columns)
# Out:
# []

# %% [markdown]
# ### Encoding des objets pour traitement

# %%
for i in df.select_dtypes('object'):
    encoded_df = pd.get_dummies(df[i])
    encoder = LabelEncoder()
    df[i] = encoder.fit_transform(df[i])

# %% [markdown]
# ### Utilisation d'un traitement au choix

# %% [markdown]
# ## Matrice de corrélation knnimputer

# %%
corr_matrix = df.corr().sort_index(axis=0).sort_index(axis=1)
plt.figure(figsize=(10, 8))  # Définir la taille de la figure
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Matrice de corrélation')
plt.show()

# %%
df=df.drop(['pH','F','HCO3','K','SO4'], axis=1)
df.head()
# Out:
#     E.C      TDS   Cl        NO3      Na    Ca      Mg         T.H       SAR  \
# 0   745   476.80   60   42.276818   49.0  48.0  38.896  279.934211  1.273328
# 1   921   589.44   80  100.659091   42.0  56.0  63.206  399.893092  0.913166
# 2   510   326.40   30   41.471545   45.0  24.0  38.896  219.934211  1.319284
# 3   422   270.08   10   10.669864   27.0  32.0  19.448  159.967105  0.928155
# 4  2321  1485.44  340  128.843636  298.0  56.0  92.378  519.843750  5.682664
#
#    Classification  RSC  meq  / L
# 0               2      -1.198684
# 1               3      -3.397862
# 2               2      -0.398684
# 3               2       0.000658
# 4               0      -4.396875

# %%
df.to_csv('result_water.csv')
